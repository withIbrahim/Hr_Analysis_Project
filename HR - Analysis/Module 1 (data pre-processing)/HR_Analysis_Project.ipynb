# %% [markdown]
# __Steps To Preform Data Preprocessing__

# %% [markdown]
# ● Removing duplicate rows.
#
# ● Removing null values from rows.
#
# ● Export the cleaned dataset as a .csv file: prefer UTF-8 encoding.
#
# ● Convert the pre-processed dataset into an SQL file.
#
# ● Manually generate a table by utilizing the database information provided in the "Database Info" tab.

# %%
#Import the Pandas library for Data Pre-processing

import pandas as pd

# %% [markdown]
# __Import the Data__

# %%
df = pd.read_csv('C:\\Users\\Ibrahim\\Dropbox\\PC\\Downloads\\Uncleaned_employees_final_dataset.csv')
df
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17414        49584                 HR   region_7  Bachelors      m
# 17415        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %% [markdown]
# Understanding how is the data structure

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  17417.000000     17417.000000  17417.000000          16054.000000
# mean   39083.491129         1.250732     34.807774              3.345459
# std    22707.024087         0.595692      7.694046              1.265386
# min        3.000000         1.000000     20.000000              1.000000
# 25%    19281.000000         1.000000     29.000000              3.000000
# 50%    39122.000000         1.000000     33.000000              3.000000
# 75%    58838.000000         1.000000     39.000000              4.000000
# max    78295.000000         9.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met_more_than_80    awards_won  \
# count       17417.000000           17417.000000  17417.000000
# mean            5.801860               0.358845      0.023368
# std             4.175533               0.479675      0.151074
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17417 entries, 0 to 17416
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            17417 non-null  int64
#  1   department             17417 non-null  object
#  2   region                 17417 non-null  object
#  3   education              16646 non-null  object
#  4   gender                 17417 non-null  object
#  5   recruitment_channel    17417 non-null  object
#  6   no_of_trainings        17417 non-null  int64
#  7   age                    17417 non-null  int64
#  8   previous_year_rating   16054 non-null  float64
#  9   length_of_service      17417 non-null  int64
#  10  KPIs_met_more_than_80  17417 non-null  int64
#  11  awards_won             17417 non-null  int64
#  12  avg_training_score     17417 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# employee_id                 0
# department                  0
# region                      0
# education                 771
# gender                      0
# recruitment_channel         0
# no_of_trainings             0
# age                         0
# previous_year_rating     1363
# length_of_service           0
# KPIs_met_more_than_80       0
# awards_won                  0
# avg_training_score          0
# dtype: int64

# %% [markdown]
# __Removing duplicate rows__

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#        employee_id         department     region  education gender  \
# 0             8724         Technology  region_26  Bachelors      m
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17410        57239  Sales & Marketing  region_31  Bachelors      m
# 17411        73858  Sales & Marketing  region_25  Bachelors      m
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# ...

# %% [markdown]
# __Removing Null values from rows__

# %%
df=df.dropna()

# %%
df
# Out:
#        employee_id         department     region  education gender  \
# 1            74430                 HR   region_4  Bachelors      f
# 2            72255  Sales & Marketing  region_13  Bachelors      m
# 3            38562        Procurement   region_2  Bachelors      f
# 4            64486            Finance  region_29  Bachelors      m
# 5            46232        Procurement   region_7  Bachelors      m
# ...            ...                ...        ...        ...    ...
# 17410        57239  Sales & Marketing  region_31  Bachelors      m
# 17411        73858  Sales & Marketing  region_25  Bachelors      m
# 17412        64573         Technology   region_7  Bachelors      f
# 17413        49584                 HR   region_7  Bachelors      m
# 17416        64573                 HR   region_7  Bachelors      f
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 1                   other                1   31                   3.0
# ...

# %%
# checking is there any null values

df.isnull().sum()
# Out:
# employee_id              0
# department               0
# region                   0
# education                0
# gender                   0
# recruitment_channel      0
# no_of_trainings          0
# age                      0
# previous_year_rating     0
# length_of_service        0
# KPIs_met_more_than_80    0
# awards_won               0
# avg_training_score       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15422 entries, 1 to 17416
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            15422 non-null  int64
#  1   department             15422 non-null  object
#  2   region                 15422 non-null  object
#  3   education              15422 non-null  object
#  4   gender                 15422 non-null  object
#  5   recruitment_channel    15422 non-null  object
#  6   no_of_trainings        15422 non-null  int64
#  7   age                    15422 non-null  int64
#  8   previous_year_rating   15422 non-null  float64
#  9   length_of_service      15422 non-null  int64
#  10  KPIs_met_more_than_80  15422 non-null  int64
#  11  awards_won             15422 non-null  int64
#  12  avg_training_score     15422 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# After Pre-processed the data we have total 15422 rows and 13 columns
# ↓↓

# %%
df.shape
# Out:
# (15422, 13)

# %% [markdown]
# Then Export the clean data for further analysis in SQL

# %%
dataset=df.to_csv('C:\\Users\\Ibrahim\\Dropbox\\PC\\Downloads\\clean_data.csv')

# %% [markdown]
# After export pre-processed dataset we should import into SQL server,
#
# then we will be working on performing data analysis using SQL on the pre-processed.
